# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
url = "https://drive.google.com/file/d/1k-GS-_YF3OH1yriZftYjjW83vtfIwOe2/view?usp=drive_link"
path = 'https://drive.google.com/uc?export=download&id='+url.split('/')[-2]
df = pd.read_csv(path)

# %%
df.head()
# Out:
#    StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0       1001   17       1          0                  2        19.833723
# 1       1002   18       0          0                  1        15.408756
# 2       1003   15       0          2                  3         4.210570
# 3       1004   17       1          0                  3        10.028829
# 4       1005   17       1          0                  2         4.672495
#
#    Absences  Tutoring  ParentalSupport  Extracurricular  Sports  Music  \
# 0         7         1                2                0       0      1
# 1         0         0                1                0       0      0
# 2        26         0                2                0       0      0
# 3        14         0                3                1       0      0
# 4        17         1                3                0       0      0
#
#    Volunteering       GPA  GradeClass
# 0             0  2.929196         2.0
# ...

# %%
df.shape
# Out:
# (2392, 15)

# %%
df.dropna
# Out:
# <bound method DataFrame.dropna of       StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0          1001   17       1          0                  2        19.833723
# 1          1002   18       0          0                  1        15.408756
# 2          1003   15       0          2                  3         4.210570
# 3          1004   17       1          0                  3        10.028829
# 4          1005   17       1          0                  2         4.672495
# ...         ...  ...     ...        ...                ...              ...
# 2387       3388   18       1          0                  3        10.680555
# 2388       3389   17       0          0                  1         7.583217
# 2389       3390   16       1          0                  2         6.805500
# 2390       3391   16       1          1                  0        12.416653
# 2391       3392   16       1          0                  2        17.819907
#
# ...

# %%
df['GradeClass'].value_counts().plot(kind='bar')
plt.xlabel('Grade Class')
plt.show()

# %%
plt.scatter(df["GPA"], df["Absences"], marker="o")
plt.show()

# %%
avg_scores = df.groupby("ParentalSupport")["GPA"].mean()
avg_scores.plot(kind='bar', figsize=(8, 5))
plt.ylabel('Average GPA')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
avg_scores = df.groupby("Ethnicity")["GPA"].mean()
avg_scores.plot(kind='bar', figsize=(8, 5))
plt.ylabel('Average GPA')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
plt.scatter(df["GPA"], df["StudyTimeWeekly"], marker="o")
plt.show()
